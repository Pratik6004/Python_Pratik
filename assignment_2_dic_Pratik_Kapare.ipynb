# %% [markdown]
# # Basic Dictionay Operations

# %% [markdown]
# 1. Create a dictionary with 3 key-value pairs (name, age, city).

# %%
person = {"name": "Pratik","age": 21,"city": "Pune"}
person
# Out:
# {'name': 'Pratik', 'age': 21, 'city': 'Pune'}

# %% [markdown]
# 2. Create a dictionary and print the value of a specific key.

# %%
dic2 = {"name": "Pratik","age": 21,"city": "Pune"}
dic2["age"]
# Out:
# 21

# %% [markdown]
# 3. Make a dictionary and add a new key-value pair to it.

# %%
dic3 = {"name": "Pratik","age": 21,"city": "Pune"}
dic3.update({"weight":80})
dic3
# Out:
# {'name': 'Pratik', 'age': 21, 'city': 'Pune', 'weight': 80}

# %% [markdown]
# 4. Create a dictionary and change the value of an existing key.

# %%
dic4 = {"name": "Pratik","age": 21,"city": "Pune"}
dic4.update({"city":"kolhapur"})
dic4
# Out:
# {'name': 'Pratik', 'age': 21, 'city': 'kolhapur'}

# %% [markdown]
# 5. Create a dictionary and remove one key using pop().

# %%
dic5 = {"name": "Pratik","age": 21,"city": "Pune"}
dic5.pop("age")
dic5
# Out:
# {'name': 'Pratik', 'city': 'Pune'}

# %% [markdown]
# 6. Create a dictionary and remove the last inserted item using popitem().

# %%
dic6 = {"name": "Pratik","age": 21,"city": "Pune"}
dic6.popitem()
dic6
# Out:
# {'name': 'Pratik', 'age': 21}

# %% [markdown]
# 7. Create a dictionary and print all the keys.

# %%
dic7 = {"name": "Pratik","age": 21,"city": "Pune"}
dic7.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %% [markdown]
# 8. Create a dictionary and print all the values.

# %%
dic8 = {"name": "Pratik","age": 21,"city": "Pune"}
dic8.values()
# Out:
# dict_values(['Pratik', 21, 'Pune'])

# %% [markdown]
# 9. Create a dictionary and print all the key-value items.

# %%
dic9 = {"name": "Pratik","age": 21,"city": "Pune"}
dic9
# Out:
# {'name': 'Pratik', 'age': 21, 'city': 'Pune'}

# %% [markdown]
# 10. Make a dictionary and check the number of items using len().

# %%
dic10 = {"name": "Pratik","age": 21,"city": "Pune"}
len(dic10)  #OR dic10.__len__()
# Out:
# 3

# %% [markdown]
# 11. Create a dictionary and check if a certain key exists (using "key" in dict).

# %%
dic11 = {"name": "Pratik","age": 21,"city": "Pune"}
"age" in dic11
# Out:
# True

# %% [markdown]
# 12. Create an empty dictionary and add two key-value pairs one by one.

# %%
dic12 = {}  #empty dic
dic12["name"]="pratik"
dic12["age"]=23
dic12
# Out:
# {'name': 'pratik', 'age': 23}

# %% [markdown]
# 13. Create a dictionary and update one key’s value using update().

# %%
dic13 = {"name": "Pratik","age": 21,"city": "Pune"}
dic13.update({"age":23})
dic13
# Out:
# {'name': 'Pratik', 'age': 23, 'city': 'Pune'}

# %% [markdown]
# 14. Create two dictionaries and combine them using update().

# %%
dic14 = {"name": "Pratik","age": 21,"city": "Pune"}
dic ={"weight":80}
dic14.update(dic)
dic14
# Out:
# {'name': 'Pratik', 'age': 21, 'city': 'Pune', 'weight': 80}

# %% [markdown]
# 15. Make a dictionary and get the value of a key using get().

# %%
dic15 = {"name": "Pratik","age": 21,"city": "Pune"}
dic15.get("age")
# Out:
# 21

# %% [markdown]
# 16. Create a dictionary and print its type using type().

# %%
dic16 = {"name": "Pratik","age": 21,"city": "Pune"}
type(dic16)
# Out:
# dict

# %% [markdown]
# 17. Create a dictionary and replace one value with a new one.

# %%
dic17 = {"name": "Pratik","age": 21,"city": "Pune"}
dic17["age"]=23
dic17
# Out:
# {'name': 'Pratik', 'age': 23, 'city': 'Pune'}

# %% [markdown]
# 18. Create a dictionary and clear all items using clear().

# %%
dic18 = {"name": "Pratik","age": 21,"city": "Pune"}
dic18.clear()
dic18
# Out:
# {}

# %% [markdown]
# 19. Create a dictionary with numbers as keys and names as values. Print the dictionary.

# %%
dic19 = {1: "Pratik",2: "Hello",3: "Pune"}
dic19
# Out:
# {1: 'Pratik', 2: 'Hello', 3: 'Pune'}

# %% [markdown]
# 20. Create a dictionary and copy it into a new dictionary using copy().

# %%
dic20 = {"name": "Pratik","age": 21,"city": "Pune"}
dic=dic20.copy()
dic
# Out:
# {'name': 'Pratik', 'age': 21, 'city': 'Pune'}
