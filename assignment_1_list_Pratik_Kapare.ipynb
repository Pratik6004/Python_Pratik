# %% [markdown]
# # Basic List Operations

# %% [markdown]
# 1. Create a list of 5 numbers and add a new number to the end.

# %%
lst=[10,20,30,40,50]
lst.append(60)
lst
# Out:
# [10, 20, 30, 40, 50, 60]

# %% [markdown]
# 2. Make a list of fruits and insert a fruit at the second position.

# %%
fruits=['apple','mango','watermelon','guava','banana']
fruits.insert(1,'grapes')
fruits
# Out:
# ['apple', 'grapes', 'mango', 'watermelon', 'guava', 'banana']

# %% [markdown]
# 3. Create a list of names and remove one name from the list.

# %%
name=['pratik','prathmesh','ashu','atharv','om']
name.pop()  #Or
name.remove('pratik')
name
# Out:
# ['prathmesh', 'ashu', 'atharv']

# %% [markdown]
# 4. Create a list of 4 items and change the value at index 2.

# %%
lst4=[100,200,300,400]
lst4[2]=500
lst4
# Out:
# [100, 200, 500, 400]

# %% [markdown]
# 5. Make a list of numbers and print only the first three elements.

# %%
lst5=[100,200,300,400,500,600]
lst5[0:3]
# Out:
# [100, 200, 300]

# %% [markdown]
# 6. Create a list of colors and find the index of a specific color.

# %%
lst6=['red','yellow','orange','blue','green']
lst6.index('yellow')
# Out:
# 1

# %% [markdown]
# 7. Create a list of 10 numbers and print how many times “5” appears.

# %%
lst7=[1,2,4,5,3,5,6,7,5,8,5]
lst7.count(5)
# Out:
# 4

# %% [markdown]
# 8. Make a list of 6 items and delete the item at index 3.

# %%
lst8=[10,20,30,40,50,60]
lst8.pop(3)
lst8
# Out:
# [10, 20, 30, 50, 60]

# %% [markdown]
# 9. Create a list of animals and add three more animals using extend().

# %%
lst9=['tiger','lion','zebra']
lst9.extend(['cow','dog','elephant'])
lst9
# Out:
# ['tiger', 'lion', 'zebra', 'cow', 'dog', 'elephant']

# %% [markdown]
# 10. Create a list and remove the last item using pop().

# %%
lst10=['tiger','lion','zebra']
lst10.pop()
lst10
# Out:
# ['tiger', 'lion']

# %% [markdown]
# 11. Create a list of prices and sort them in ascending order.

# %%
lst11=[200,84,500,300,400,100]
lst11.sort()
lst11
# Out:
# [84, 100, 200, 300, 400, 500]

# %% [markdown]
# 12. Make a list of countries and reverse the order of the list.

# %%
lst12=['india','usa','germany','china']
lst12.reverse()
lst12
# Out:
# ['china', 'germany', 'usa', 'india']

# %% [markdown]
# 13. Create a list of words and check if “apple” is in the list.

# %%
lst13=['apple','mango','watermelon','guava','banana']
'apple' in lst13
# lst13
# Out:
# True

# %% [markdown]
# 14. Create a list of numbers and print the largest and smallest number.

# %%
lst14=[200,84,500,300,400,100]
print('largest number:',max(lst14))
print('smallest number:',min(lst14))
# print('largest number:',max_no)
# print('smallest number:',small_no)
# Out:
# largest number: 500
# smallest number: 84

# %% [markdown]
# 15. Make a list of 5 items and print each item using a loop.

# %%
lst15=['apple','mango','watermelon','guava','banana']
for i in lst15:
    print(i)
# Out:
# apple
# mango
# watermelon
# guava
# banana

# %% [markdown]
# 16. Create two lists and combine them into one list.

# %%
lst=["apple","mango","watermelon"]
lst2=[200,84,500,300,400,100]
lst.extend(lst2)
lst
# Out:
# ['apple', 'mango', 'watermelon', 200, 84, 500, 300, 400, 100]

# %% [markdown]
# 17. Make a list and replace the last item with a new value.

# %%
lst17=["apple","mango","watermelon"]
lst17[-1]=40
lst17
# Out:
# ['apple', 'mango', 40]

# %% [markdown]
# 18. Create a list of numbers and print only the even numbers.

# %%
lst18=[200,83,501,302,405,100]
for i in lst18:
    if(i%2==0):
        print(i)
# Out:
# 200
# 302
# 100

# %% [markdown]
# 19. Create a list and clear all items from the list.

# %%
lst19=[200,83,501,302,405,100]
lst19.clear()
lst19
# Out:
# []

# %% [markdown]
# 20. Create a list of 5 values and copy it into another list.

# %%
lst20=[200,83,501,302,405]
lst21=[]
lst21=lst20.copy()
lst21
# Out:
# [200, 83, 501, 302, 405]
